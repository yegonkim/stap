# %%
import h5py
import torch
import numpy as np
import matplotlib.pyplot as plt

# with h5py.File(f'data_large/Burgers_train_100000_default.h5', 'r') as f:
#     # Traj_dataset.traj_train = torch.tensor(f['train']['pde_140-256'][:10000, :131], dtype=torch.float32, device=cfg.device)
#     traj = torch.tensor(f['train']['pde_140-256'][:1000, :131], dtype=torch.float32)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
import hydra
from omegaconf import DictConfig, OmegaConf
from generate_data import evolve
from tqdm import tqdm

hydra.initialize(config_path="cfg_flexible", version_base=None)
cfg = hydra.compose(config_name="config", overrides=["task=KdV", "nt=131"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       3 from generate_data import evolve
#       4 from tqdm import tqdm
# ----> 6 hydra.initialize(config_path="cfg_flexible", version_base=None)
#       7 cfg = hydra.compose(config_name="config", overrides=["task=KdV", "nt=131"])
#
# File ~/.conda/envs/lupi/lib/python3.10/site-packages/hydra/initialize.py:91, in initialize.__init__(self, config_path, job_name, caller_stack_depth, version_base)
#      86 if job_name is None:
#      87     job_name = detect_task_name(
#      88         calling_file=calling_file, calling_module=calling_module
#      89     )
# ---> 91 Hydra.create_main_hydra_file_or_module(
#      92     calling_file=calling_file,
#      93     calling_module=calling_module,
#      94     config_path=config_path,
#      95     job_name=job_name,
#      96 )
#
# File ~/.conda/envs/lupi/lib/python3.10/site-packages/hydra/_internal/hydra.py:53, in Hydra.create_main_hydra_file_or_module(cls, calling_file, calling_module, config_path, job_name)
#      41 @classmethod
#      42 def create_main_hydra_file_or_module(
#      43     cls: Type["Hydra"],
#    (...)
#      47     job_name: str,
#      48 ) -> "Hydra":
#      49     config_search_path = create_automatic_config_search_path(
#      50         calling_file, calling_module, config_path
#      51     )
# ---> 53     return Hydra.create_main_hydra2(job_name, config_search_path)
#
# File ~/.conda/envs/lupi/lib/python3.10/site-packages/hydra/_internal/hydra.py:68, in Hydra.create_main_hydra2(cls, task_name, config_search_path)
#      65 hydra = cls(task_name=task_name, config_loader=config_loader)
#      66 from hydra.core.global_hydra import GlobalHydra
# ---> 68 GlobalHydra.instance().initialize(hydra)
#      69 return hydra
#
# File ~/.conda/envs/lupi/lib/python3.10/site-packages/hydra/core/global_hydra.py:16, in GlobalHydra.initialize(self, hydra)
#      14 assert isinstance(hydra, Hydra), f"Unexpected Hydra type : {type(hydra)}"
#      15 if self.is_initialized():
# ---> 16     raise ValueError(
#      17         "GlobalHydra is already initialized, call GlobalHydra.instance().clear() if you want to re-initialize"
#      18     )
#      19 self.hydra = hydra
#
# ValueError: GlobalHydra is already initialized, call GlobalHydra.instance().clear() if you want to re-initialize

# %%
with h5py.File(cfg.dataset.train_path, 'r') as f:
    # Traj_dataset.traj_train = torch.tensor(f['train']['pde_140-256'][:10000, :131], dtype=torch.float32, device=cfg.device)
    traj = torch.tensor(f['train']['pde'][:1000, :131], dtype=torch.float32)

# %%
print(traj.shape)
# Out:
# torch.Size([1000, 131, 1, 256])

# %%
for i in range(500,510):
    plt.figure(figsize=(6,4))  # Increase width, retain height
    plt.imshow(traj[i,:,0].cpu().numpy().T, aspect='auto')  # Set aspect ratio to 'auto'
    plt.xlabel('t')
    plt.ylabel('x')
    plt.show()
