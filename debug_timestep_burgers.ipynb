# %%
import hydra
from omegaconf import DictConfig, OmegaConf
from generate_data import evolve
from tqdm import tqdm
import os
os.environ['XLA_PYTHON_CLIENT_MEM_FRACTION'] = ".30" # proportion of memory preallocated for jax
hydra.initialize(config_path="cfg_flexible", version_base=None)
cfg = hydra.compose(config_name="config", overrides=["task=Burgers"])

# %%
import h5py
import torch
import numpy as np
import matplotlib.pyplot as plt

with h5py.File(cfg.dataset.train_path, 'r') as f:
    # Traj_dataset.traj_train = torch.tensor(f['train']['pde_140-256'][:10000, :131], dtype=torch.float32, device=cfg.device)
    traj = torch.tensor(f['train']['pde'][:1000, :131], dtype=torch.float32)

# %%
traj.shape
# Out:
# torch.Size([1000, 131, 1, 256])

# %%
plt.imshow(traj[401,:,0].cpu().numpy())

# %%
u0 = traj[0:1, 0, :]

# %%
u0.shape
# Out:
# torch.Size([1, 1, 256])

# %%
from generate_data import EvolveJax

evolve_jax = EvolveJax(cfg)
traj = evolve_jax(u0,0,140)
# Out:
# number of ICs to be processed: 2
# compiling jax sim

# %%
import hydra
from omegaconf import DictConfig, OmegaConf
from generate_data import evolve
from tqdm import tqdm

hydra.initialize(config_path="cfg_flexible", version_base=None)
cfg = hydra.compose(config_name="config", overrides=["task=NS_rey"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 6
#       3 from generate_data import evolve
#       4 from tqdm import tqdm
# ----> 6 hydra.initialize(config_path="cfg_flexible", version_base=None)
#       7 cfg = hydra.compose(config_name="config", overrides=["task=NS_rey"])
#
# File ~/miniconda3/envs/lupi/lib/python3.10/site-packages/hydra/initialize.py:91, in initialize.__init__(self, config_path, job_name, caller_stack_depth, version_base)
#      86 if job_name is None:
#      87     job_name = detect_task_name(
#      88         calling_file=calling_file, calling_module=calling_module
#      89     )
# ---> 91 Hydra.create_main_hydra_file_or_module(
#      92     calling_file=calling_file,
#      93     calling_module=calling_module,
#      94     config_path=config_path,
#      95     job_name=job_name,
#      96 )
#
# File ~/miniconda3/envs/lupi/lib/python3.10/site-packages/hydra/_internal/hydra.py:53, in Hydra.create_main_hydra_file_or_module(cls, calling_file, calling_module, config_path, job_name)
#      41 @classmethod
#      42 def create_main_hydra_file_or_module(
#      43     cls: Type["Hydra"],
#    (...)
#      47     job_name: str,
#      48 ) -> "Hydra":
#      49     config_search_path = create_automatic_config_search_path(
#      50         calling_file, calling_module, config_path
#      51     )
# ---> 53     return Hydra.create_main_hydra2(job_name, config_search_path)
#
# File ~/miniconda3/envs/lupi/lib/python3.10/site-packages/hydra/_internal/hydra.py:68, in Hydra.create_main_hydra2(cls, task_name, config_search_path)
#      65 hydra = cls(task_name=task_name, config_loader=config_loader)
#      66 from hydra.core.global_hydra import GlobalHydra
# ---> 68 GlobalHydra.instance().initialize(hydra)
#      69 return hydra
#
# File ~/miniconda3/envs/lupi/lib/python3.10/site-packages/hydra/core/global_hydra.py:16, in GlobalHydra.initialize(self, hydra)
#      14 assert isinstance(hydra, Hydra), f"Unexpected Hydra type : {type(hydra)}"
#      15 if self.is_initialized():
# ---> 16     raise ValueError(
#      17         "GlobalHydra is already initialized, call GlobalHydra.instance().clear() if you want to re-initialize"
#      18     )
#      19 self.hydra = hydra
#
# ValueError: GlobalHydra is already initialized, call GlobalHydra.instance().clear() if you want to re-initialize

# %%
# x = generate_ic(10, cfg).unsqueeze(1)
# print(x.shape)
# y = evolve(x, cfg, timesteps=13)
# print(y.shape)

# %%
# plt.imshow(y[0].cpu().numpy())

# %%
with h5py.File(cfg.dataset.train_path, 'r') as f:
    # Traj_dataset.traj_train = torch.tensor(f['train']['pde_140-256'][:10000, :131], dtype=torch.float32, device=cfg.device)
    traj = torch.tensor(f['train']['pde'][:1000, :131], dtype=torch.float32)

# %%
print(traj.shape)
# Out:
# torch.Size([1000, 131, 1, 32, 32])

# %%
plt.figure(figsize=(50,10))
for t in range(14):
    plt.subplot(1,14,t+1)
    plt.imshow(traj[3,t*10,0].cpu().numpy().T)

# %%
x = traj[1:2, 0, :]

solution = evolve(x, cfg, timesteps=13)


real = traj[1:2, 0::10, :]

# %%
real = real[:,1:]

# %%
real.shape, solution.shape
# Out:
# (torch.Size([1, 13, 1, 32, 32]), torch.Size([1, 13, 1, 32, 32]))

# %%
((real - solution)**2).mean()
# Out:
# tensor(9.6441e-09)

# %%
x = traj[0:1, :1, :]+2*torch.randn(1, 1, 256)

solution = evolve(x, cfg, timesteps=1)


real = traj[0:1, :, :]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x = traj[0:1, :1, :]+2*torch.randn(1, 1, 256)
#       3 solution = evolve(x, cfg, timesteps=1)
#       6 real = traj[0:1, :, :]
#
# RuntimeError: The size of tensor a (32) must match the size of tensor b (256) at non-singleton dimension 4

# %%
((real[:,1] - solution)**2).mean(dim=(0,2))
# Out:
# tensor([0.8074])

# %%
x = traj[0:10, :1, :]
solution = []
y_pred = x
solution.append(y_pred)
for i in tqdm(range(cfg.nt-1)):
    y_pred = generate_timestep(solution[-1], cfg)
    solution.append(y_pred)
solution = torch.cat(solution, dim=1)

real = traj[0:10, :131, :]
# Out:
#   2%|▏         | 3/130 [00:00<00:12, 10.27it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#   4%|▍         | 5/130 [00:00<00:11, 10.54it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#   7%|▋         | 9/130 [00:00<00:11, 10.53it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#   8%|▊         | 11/130 [00:01<00:11, 10.68it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  12%|█▏        | 15/130 [00:01<00:10, 10.81it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  13%|█▎        | 17/130 [00:01<00:10, 10.94it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  16%|█▌        | 21/130 [00:01<00:09, 11.39it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  18%|█▊        | 23/130 [00:02<00:09, 10.91it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  19%|█▉        | 25/130 [00:02<00:09, 10.70it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  22%|██▏       | 29/130 [00:02<00:09, 10.22it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  24%|██▍       | 31/130 [00:02<00:09, 10.58it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  27%|██▋       | 35/130 [00:03<00:08, 11.48it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  28%|██▊       | 37/130 [00:03<00:08, 11.59it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  32%|███▏      | 41/130 [00:03<00:07, 12.39it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  33%|███▎      | 43/130 [00:03<00:06, 12.62it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  36%|███▌      | 47/130 [00:04<00:06, 12.42it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  38%|███▊      | 49/130 [00:04<00:06, 12.34it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  41%|████      | 53/130 [00:04<00:06, 12.51it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  42%|████▏     | 55/130 [00:04<00:06, 12.41it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  45%|████▌     | 59/130 [00:05<00:05, 12.31it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  47%|████▋     | 61/130 [00:05<00:05, 12.32it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  50%|█████     | 65/130 [00:05<00:05, 12.35it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  52%|█████▏    | 67/130 [00:05<00:05, 12.37it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  55%|█████▍    | 71/130 [00:06<00:04, 12.60it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  56%|█████▌    | 73/130 [00:06<00:04, 12.44it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  59%|█████▉    | 77/130 [00:06<00:04, 12.39it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  61%|██████    | 79/130 [00:06<00:04, 12.65it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  64%|██████▍   | 83/130 [00:07<00:03, 12.58it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  65%|██████▌   | 85/130 [00:07<00:03, 12.58it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  68%|██████▊   | 89/130 [00:07<00:03, 12.50it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  70%|███████   | 91/130 [00:07<00:03, 12.57it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  73%|███████▎  | 95/130 [00:07<00:02, 13.14it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  75%|███████▍  | 97/130 [00:08<00:02, 13.38it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  78%|███████▊  | 101/130 [00:08<00:02, 13.30it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  79%|███████▉  | 103/130 [00:08<00:02, 13.17it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  82%|████████▏ | 107/130 [00:08<00:01, 13.31it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  84%|████████▍ | 109/130 [00:09<00:01, 13.36it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  87%|████████▋ | 113/130 [00:09<00:01, 13.52it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  88%|████████▊ | 115/130 [00:09<00:01, 13.59it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  92%|█████████▏| 119/130 [00:09<00:00, 13.64it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  93%|█████████▎| 121/130 [00:09<00:00, 13.48it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  96%|█████████▌| 125/130 [00:10<00:00, 13.12it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  98%|█████████▊| 127/130 [00:10<00:00, 12.67it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# 100%|██████████| 130/130 [00:10<00:00, 12.22it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])

# %%
plt.figure()
plt.imshow(real[0].cpu().numpy().T)
plt.colorbar()

plt.figure()
plt.imshow(solution[0].cpu().numpy().T)
plt.colorbar()

print(torch.norm(real-solution) / torch.norm(real))
# Out:
# tensor(5.7923e-07)
