# %%
import h5py
import torch
import numpy as np
import matplotlib.pyplot as plt
import hydra

# with h5py.File(f'data_large/Burgers_train_100000_default.h5', 'r') as f:
#     # Traj_dataset.traj_train = torch.tensor(f['train']['pde_140-256'][:10000, :131], dtype=torch.float32, device=cfg.device)
#     traj = torch.tensor(f['train']['pde_140-256'][:1000, :131], dtype=torch.float32)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
hydra.initialize(config_path="cfg_flexible", version_base=None)
# Out:
# hydra.initialize()

# %%
from omegaconf import DictConfig, OmegaConf
from generate_data import evolve
from tqdm import tqdm

cfg = hydra.compose(config_name="config", overrides=["task=KdV", "nt=14"])

# %%
with h5py.File(cfg.dataset.train_path, 'r') as f:
    # Traj_dataset.traj_train = torch.tensor(f['train']['pde_140-256'][:10000, :131], dtype=torch.float32, device=cfg.device)
    traj = torch.tensor(f['train']['pde'][:1000, :131], dtype=torch.float32)

# %%
# plt.figure()
# plt.imshow(traj[0,:,0].cpu().numpy().T)
# plt.colorbar()

# %%
x = traj[0:1, 0, :]

print(x.shape)

solution = evolve(x, cfg, timesteps=1)



real = traj[0:1, 1:131, :]
# Out:
# torch.Size([1, 1, 256])

# %%
u = x.clone()
print(u.norm())
# solution = evolve(u, cfg, timesteps=1)
# Out:
# tensor(6.8639)

# %%
solution = evolve(u*3, cfg, timesteps=1)

# %%
for scale in [10]:
    print(scale)
    u = x*scale
    print(u.norm())
    u = u.to(device)
    solution = evolve(u, cfg, timesteps=1)
# Out:
# 10
# tensor(68.6387)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/home/lupi/generate_data.py:654, in _evolve_ps(u0, cfg, t0, timesteps, dt)
#     652 t = torch.tensor(t).to(device)
# --> 654 solved_trajectory = odeint(func=spectral_method,
#     655                             t=t,
#     656                             y0=u,
#     657                             method=cfg.generate_data.solver,
#     658                             atol=atol,
#     659                             rtol=rtol)
#     660 sol = solved_trajectory.permute(1,0,2) # (n_data, nt, nx)
#
# File ~/miniconda3/envs/lupi/lib/python3.10/site-packages/torchdiffeq/_impl/odeint.py:77, in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      76 if event_fn is None:
# ---> 77     solution = solver.integrate(t)
#      78 else:
#
# File ~/miniconda3/envs/lupi/lib/python3.10/site-packages/torchdiffeq/_impl/solvers.py:30, in AdaptiveStepsizeODESolver.integrate(self, t)
#      29 for i in range(1, len(t)):
# ---> 30     solution[i] = self._advance(t[i])
#      31 return solution
#
# File ~/miniconda3/envs/lupi/lib/python3.10/site-packages/torchdiffeq/_impl/rk_common.py:194, in RKAdaptiveStepsizeODESolver._advance(self, next_t)
#     193 assert n_steps < self.max_num_steps, 'max_num_steps exceeded ({}>={})'.format(n_steps, self.max_num_steps)
# --> 194 self.rk_state = self._adaptive_step(self.rk_state)
#     195 n_steps += 1
#
# File ~/miniconda3/envs/lupi/lib/python3.10/site-packages/torchdiffeq/_impl/rk_common.py:228, in RKAdaptiveStepsizeODESolver._adaptive_step(self, rk_state)
#     216 # dtypes: self.y0.dtype (probably float32); self.dtype (probably float64)
#     217 # used for state and timelike objects respectively.
#     218 # Then:
#    (...)
#     226 #                      Assertions                      #
#     227 ########################################################
# --> 228 assert t0 + dt > t0, 'underflow in dt {}'.format(dt.item())
#     229 assert torch.isfinite(y0).all(), 'non-finite values in state `y`: {}'.format(y0)
#
# AssertionError: underflow in dt 2.5856902604880594e-17
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 6
#       4 print(u.norm())
#       5 u = u.to(device)
# ----> 6 solution = evolve(u, cfg, timesteps=1)
#
# File ~/miniconda3/envs/lupi/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/home/lupi/generate_data.py:556, in evolve(u0, cfg, t0, timesteps)
#     553 @torch.no_grad()
#     554 def evolve(u0, cfg, t0=0, timesteps=1):
#     555     if cfg.equation in ["KdV", "Heat", "nKdV", "cKdV", "Burgers"]:
# --> 556         return _evolve_ps(u0, cfg, t0, timesteps)
#     557     elif cfg.equation in ["NS", "KS"]:
#     558         return _evolve_sim(u0, cfg, t0, timesteps)
#
# File ~/home/lupi/generate_data.py:667, in _evolve_ps(u0, cfg, t0, timesteps, dt)
#     665         sol = sol.cpu() # (n_data, nt, nx)
#     666     except AssertionError:
# --> 667         raise Exception('An error occured - possibly an underflow.')
#     668     solution.append(sol)
#     669 solution = torch.cat(solution, dim=0) # (n_data, nt, nx)
#
# Exception: An error occured - possibly an underflow.

# %%
plt.figure()
plt.imshow(real[0,:,0].cpu().numpy().T)

plt.figure()
plt.imshow(solution[0,:,0].cpu().numpy().T)

# %%
((real - solution)**2).mean()
# Out:
# tensor(1.3059e-09)

# %%
x = traj[0:1, :1, :]+2*torch.randn(1, 1, 256)

solution = evolve(x, cfg, timesteps=1)


real = traj[0:1, :, :]
# Out:
# tensor(6.5467) tensor(-6.3043) torch.Size([1, 1, 256])

# %%
((real[:,1] - solution)**2).mean(dim=(0,2))
# Out:
# tensor([0.8074])

# %%
x = traj[0:10, :1, :]
solution = []
y_pred = x
solution.append(y_pred)
for i in tqdm(range(cfg.nt-1)):
    y_pred = generate_timestep(solution[-1], cfg)
    solution.append(y_pred)
solution = torch.cat(solution, dim=1)

real = traj[0:10, :131, :]
# Out:
#   2%|▏         | 3/130 [00:00<00:12, 10.27it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#   4%|▍         | 5/130 [00:00<00:11, 10.54it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#   7%|▋         | 9/130 [00:00<00:11, 10.53it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#   8%|▊         | 11/130 [00:01<00:11, 10.68it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  12%|█▏        | 15/130 [00:01<00:10, 10.81it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  13%|█▎        | 17/130 [00:01<00:10, 10.94it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  16%|█▌        | 21/130 [00:01<00:09, 11.39it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  18%|█▊        | 23/130 [00:02<00:09, 10.91it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  19%|█▉        | 25/130 [00:02<00:09, 10.70it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  22%|██▏       | 29/130 [00:02<00:09, 10.22it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  24%|██▍       | 31/130 [00:02<00:09, 10.58it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  27%|██▋       | 35/130 [00:03<00:08, 11.48it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  28%|██▊       | 37/130 [00:03<00:08, 11.59it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  32%|███▏      | 41/130 [00:03<00:07, 12.39it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  33%|███▎      | 43/130 [00:03<00:06, 12.62it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  36%|███▌      | 47/130 [00:04<00:06, 12.42it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  38%|███▊      | 49/130 [00:04<00:06, 12.34it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  41%|████      | 53/130 [00:04<00:06, 12.51it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  42%|████▏     | 55/130 [00:04<00:06, 12.41it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  45%|████▌     | 59/130 [00:05<00:05, 12.31it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  47%|████▋     | 61/130 [00:05<00:05, 12.32it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  50%|█████     | 65/130 [00:05<00:05, 12.35it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  52%|█████▏    | 67/130 [00:05<00:05, 12.37it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  55%|█████▍    | 71/130 [00:06<00:04, 12.60it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  56%|█████▌    | 73/130 [00:06<00:04, 12.44it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  59%|█████▉    | 77/130 [00:06<00:04, 12.39it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  61%|██████    | 79/130 [00:06<00:04, 12.65it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  64%|██████▍   | 83/130 [00:07<00:03, 12.58it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  65%|██████▌   | 85/130 [00:07<00:03, 12.58it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  68%|██████▊   | 89/130 [00:07<00:03, 12.50it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  70%|███████   | 91/130 [00:07<00:03, 12.57it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  73%|███████▎  | 95/130 [00:07<00:02, 13.14it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  75%|███████▍  | 97/130 [00:08<00:02, 13.38it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  78%|███████▊  | 101/130 [00:08<00:02, 13.30it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  79%|███████▉  | 103/130 [00:08<00:02, 13.17it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  82%|████████▏ | 107/130 [00:08<00:01, 13.31it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  84%|████████▍ | 109/130 [00:09<00:01, 13.36it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  87%|████████▋ | 113/130 [00:09<00:01, 13.52it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  88%|████████▊ | 115/130 [00:09<00:01, 13.59it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  92%|█████████▏| 119/130 [00:09<00:00, 13.64it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  93%|█████████▎| 121/130 [00:09<00:00, 13.48it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  96%|█████████▌| 125/130 [00:10<00:00, 13.12it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
#  98%|█████████▊| 127/130 [00:10<00:00, 12.67it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])
# 100%|██████████| 130/130 [00:10<00:00, 12.22it/s]
# torch.Size([10, 1, 256])
# torch.Size([10, 1, 256])

# %%
plt.figure()
plt.imshow(real[0].cpu().numpy().T)
plt.colorbar()

plt.figure()
plt.imshow(solution[0].cpu().numpy().T)
plt.colorbar()

print(torch.norm(real-solution) / torch.norm(real))
# Out:
# tensor(5.7923e-07)
